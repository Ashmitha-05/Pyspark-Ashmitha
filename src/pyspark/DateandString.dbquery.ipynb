-- %%
CREATE TABLE EmployeeOrders
(
    order_id INT,
    customer_name VARCHAR(50),
    email VARCHAR(100),
    city VARCHAR(50),
    order_date DATE,
    delivery_date DATE,
    amount DECIMAL(10,2)
);

INSERT INTO EmployeeOrders VALUES
(101,' Ash ','ash@gmail.com',' Bangalore ','2026-01-05','2026-01-08',1200),
(102,'rahul','rahul@yahoo.com','Chennai','2026-02-10','2026-02-15',1800),
(103,'PRIYA','priya@gmail.com','Hyderabad ','2026-03-15','2026-03-18',2500),
(104,'Kiran','kiran@outlook.com',' Bangalore','2026-03-22','2026-03-30',3200),
(105,'Meena ','meena@gmail.com','Delhi','2026-04-10','2026-04-12',1500),
(106,'Arun','arun@yahoo.com','Mumbai ','2026-05-08','2026-05-13',2100),
(107,' Divya','divya@gmail.com','Chennai ','2026-06-11','2026-06-16',2800),
(108,'RAVI','ravi@gmail.com','Hyderabad','2026-07-01','2026-07-03',1700);
