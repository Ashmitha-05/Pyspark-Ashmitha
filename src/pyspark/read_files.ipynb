# %%
df=spark.read.csv("/Volumes/workspace/default/volume/employees.csv",header=True,inferSchema=True)
df.show()

# %%
df.printSchema()

# %%
from pyspark.sql.types import *
myschema=StructType
(
    [
        StructField("id",IntegerType(),True),
        StructField("name",StringType(),True),
        StructField("department",StringType(),True),
        StructField("salary",IntegerType(),True)
    ]
)
df=spark.read.csv("/Volumes/workspace/default/volume/employees.csv",header=True,schema=myschema)

# %%
df=spark.read.json("/Volumes/pyspark/default/volume/employees.json")

# %%
df=spark.read.csv("/Volumes/pyspark/default/volume/employees.csv")

dff=df.write.mode("overwrite").format("parquet").save("/Volumes/pyspark/default/volume/employees_Parquet")

df=spark.read.json("/Volumes/pyspark/default/volume/employees.json")
